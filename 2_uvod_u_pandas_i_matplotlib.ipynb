# %%
# previous seminar was about numpy
import numpy

# today we learn about pandas
import pandas

# %% [markdown]
# ## Plotting in Jupyter with matplotlib
#
# below we use a **magic function**. It is a term!

# %%
import matplotlib.pyplot as plt
# magic says: activate matplotlib, show plots inline
# %matplotlib inline

# %%
x = numpy.array([-3, -1.5, 0, 1, 3, 4])

print (x)
print (x ** 2) # squared each element
# Out:
# [-3.  -1.5  0.   1.   3.   4. ]
# [ 9.    2.25  0.    1.    9.   16.  ]

# %%
plt.plot(x, x ** 2)

# %%
distribution = numpy.random.normal(loc=1., scale=2, size=10000)
plt.hist(distribution)
pass # it is the way to suppress printing output of last line. pass = 'do nothing'

# %%
plt.hist(numpy.random.normal(loc=5., scale=2, size=10000), bins=30, alpha=0.4,  label='first')
plt.hist(numpy.random.normal(loc=7., scale=3, size=10000), bins=30, alpha=0.4,  label='second')
plt.hist(numpy.random.normal(loc=0., scale=1, size=10000), bins=30, alpha=0.4,  label='third')
plt.legend()
pass

# %%
# Large scatter plot
plt.figure(figsize=[12, 10])
plt.scatter(numpy.random.normal(size=300), numpy.random.normal(size=300))

# %% [markdown]
# ## Magics
#
# magics are not needed so far, those are just for the information

# %%
# sample two arrays of random numbers sampled from uniform [0, 1]
a = numpy.random.random(size=1000000)
# %time b = numpy.random.random(size=1000000)
# measure time needed for operation
# %time result = a + b
# Out:
# CPU times: user 12.3 ms, sys: 5.02 ms, total: 17.3 ms
# Wall time: 17.3 ms
# CPU times: user 1.11 ms, sys: 3.9 ms, total: 5.02 ms
# Wall time: 5.03 ms

# %%
# %%time
# measure the time needed to run whole cell (%%, not %)
a = numpy.random.random(size=1000000)
b = numpy.random.random(size=1000000)
result = a + b
# Out:
# CPU times: user 29.1 ms, sys: 8.89 ms, total: 38 ms
# Wall time: 40.3 ms

# %%
# %%prun
# profiling of complex code
numpy.histogram(x)

# %%
# general info about magics in Jupyter
# %magic

# %% [markdown]
# # Hello Pandas
#
# Looking at the data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !head /content/drive/MyDrive/Colab\ Notebooks/data/2-winequality-white.csv
# Out:
# "fixed acidity";"volatile acidity";"citric acid";"residual sugar";"chlorides";"free sulfur dioxide";"total sulfur dioxide";"density";"pH";"sulphates";"alcohol";"quality"
# 7;0.27;0.36;20.7;0.045;45;170;1.001;3;0.45;8.8;6
# 6.3;0.3;0.34;1.6;0.049;14;132;0.994;3.3;0.49;9.5;6
# 8.1;0.28;0.4;6.9;0.05;30;97;0.9951;3.26;0.44;10.1;6
# 7.2;0.23;0.32;8.5;0.058;47;186;0.9956;3.19;0.4;9.9;6
# 7.2;0.23;0.32;8.5;0.058;47;186;0.9956;3.19;0.4;9.9;6
# 8.1;0.28;0.4;6.9;0.05;30;97;0.9951;3.26;0.44;10.1;6
# 6.2;0.32;0.16;7;0.045;30;136;0.9949;3.18;0.47;9.6;6
# 7;0.27;0.36;20.7;0.045;45;170;1.001;3;0.45;8.8;6
# 6.3;0.3;0.34;1.6;0.049;14;132;0.994;3.3;0.49;9.5;6

# %%
data = pandas.read_csv('/content/drive/MyDrive/Colab Notebooks/data/2-winequality-white.csv', sep=';')
data.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
# 5            8.1              0.28         0.40             6.9      0.050
# 6            6.2              0.32         0.16             7.0      0.045
# 7            7.0              0.27         0.36            20.7      0.045
# 8            6.3              0.30         0.34             1.6      0.049
# 9            8.1              0.22         0.43             1.5      0.044
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
# 5                 30.0                  97.0   0.9951  3.26       0.44
# 6                 30.0                 136.0   0.9949  3.18       0.47
# 7                 45.0                 170.0   1.0010  3.00       0.45
# 8                 14.0                 132.0   0.9940  3.30       0.49
# 9                 28.0                 129.0   0.9938  3.22       0.45
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# 3      9.9        6
# 4      9.9        6
# 5     10.1        6
# 6      9.6        6
# 7      8.8        6
# 8      9.5        6
# 9     11.0        6

# %%
# split into description and target
y = data['quality']
X = data.drop('quality', axis=1)

# %%
X.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
# 5            8.1              0.28         0.40             6.9      0.050
# 6            6.2              0.32         0.16             7.0      0.045
# 7            7.0              0.27         0.36            20.7      0.045
# 8            6.3              0.30         0.34             1.6      0.049
# 9            8.1              0.22         0.43             1.5      0.044
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
# 5                 30.0                  97.0   0.9951  3.26       0.44
# 6                 30.0                 136.0   0.9949  3.18       0.47
# 7                 45.0                 170.0   1.0010  3.00       0.45
# 8                 14.0                 132.0   0.9940  3.30       0.49
# 9                 28.0                 129.0   0.9938  3.22       0.45
#
#    alcohol
# 0      8.8
# 1      9.5
# 2     10.1
# 3      9.9
# 4      9.9
# 5     10.1
# 6      9.6
# 7      8.8
# 8      9.5
# 9     11.0

# %% [markdown]
# ## Operations on data with pandas

# %%
#leaving only 8 rows for testing
test_frame = data[:8].copy()

# %%
test_frame
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
# 5            8.1              0.28         0.40             6.9      0.050
# 6            6.2              0.32         0.16             7.0      0.045
# 7            7.0              0.27         0.36            20.7      0.045
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
# 5                 30.0                  97.0   0.9951  3.26       0.44
# 6                 30.0                 136.0   0.9949  3.18       0.47
# 7                 45.0                 170.0   1.0010  3.00       0.45
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# 3      9.9        6
# 4      9.9        6
# 5     10.1        6
# 6      9.6        6
# 7      8.8        6

# %%
test_frame['density']
# Out:
# 0    1.0010
# 1    0.9940
# 2    0.9951
# 3    0.9956
# 4    0.9956
# 5    0.9951
# 6    0.9949
# 7    1.0010
# Name: density, dtype: float64

# %%
# converting to numpy.array with .values
test_frame['density'].values
# Out:
# array([1.001 , 0.994 , 0.9951, 0.9956, 0.9956, 0.9951, 0.9949, 1.001 ])

# %%
test_frame['fixed acidity'][:5]
# Out:
# 0    7.0
# 1    6.3
# 2    8.1
# 3    7.2
# 4    7.2
# Name: fixed acidity, dtype: float64

# %%
# indexing with numbers - iloc
test_frame.iloc[[0, 4, 7], 2:7]
# Out:
#    citric acid  residual sugar  chlorides  free sulfur dioxide  \
# 0         0.36            20.7      0.045                 45.0
# 4         0.32             8.5      0.058                 47.0
# 7         0.36            20.7      0.045                 45.0
#
#    total sulfur dioxide
# 0                 170.0
# 4                 186.0
# 7                 170.0

# %%
# indexing with named labels - loc
test_frame.loc[:, ['volatile acidity', 'fixed acidity']]
# Out:
#    volatile acidity  fixed acidity
# 0              0.27            7.0
# 1              0.30            6.3
# 2              0.28            8.1
# 3              0.23            7.2
# 4              0.23            7.2
# 5              0.28            8.1
# 6              0.32            6.2
# 7              0.27            7.0

# %%
# shortcut for previous
test_frame[['volatile acidity', 'fixed acidity']]
# Out:
#    volatile acidity  fixed acidity
# 0              0.27            7.0
# 1              0.30            6.3
# 2              0.28            8.1
# 3              0.23            7.2
# 4              0.23            7.2
# 5              0.28            8.1
# 6              0.32            6.2
# 7              0.27            7.0

# %%
# [start:end:step], some of arguments can be omitted.
test_frame.iloc[::3, ::-1]
# Out:
#    quality  alcohol  sulphates    pH  density  total sulfur dioxide  \
# 0        6      8.8       0.45  3.00   1.0010                 170.0
# 3        6      9.9       0.40  3.19   0.9956                 186.0
# 6        6      9.6       0.47  3.18   0.9949                 136.0
#
#    free sulfur dioxide  chlorides  residual sugar  citric acid  \
# 0                 45.0      0.045            20.7         0.36
# 3                 47.0      0.058             8.5         0.32
# 6                 30.0      0.045             7.0         0.16
#
#    volatile acidity  fixed acidity
# 0              0.27            7.0
# 3              0.23            7.2
# 6              0.32            6.2

# %%
# adding new feature with vector operation
test_frame['dioxide sum'] = test_frame['total sulfur dioxide'] + test_frame['free sulfur dioxide']
test_frame
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
# 5            8.1              0.28         0.40             6.9      0.050
# 6            6.2              0.32         0.16             7.0      0.045
# 7            7.0              0.27         0.36            20.7      0.045
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
# 5                 30.0                  97.0   0.9951  3.26       0.44
# 6                 30.0                 136.0   0.9949  3.18       0.47
# 7                 45.0                 170.0   1.0010  3.00       0.45
#
#    alcohol  quality  dioxide sum
# 0      8.8        6        215.0
# 1      9.5        6        146.0
# 2     10.1        6        127.0
# 3      9.9        6        233.0
# 4      9.9        6        233.0
# 5     10.1        6        127.0
# 6      9.6        6        166.0
# 7      8.8        6        215.0

# %%
# filtering dataset
filtered_data = data[data['density'] < 0.988]
filtered_data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 2945            4.9             0.330         0.31             1.2      0.016
# 3367            6.0             0.290         0.25             1.4      0.033
# 3370            6.0             0.290         0.25             1.4      0.033
# 3673            5.4             0.300         0.30             1.2      0.029
# 3676            5.3             0.300         0.30             1.2      0.029
# 3710            4.7             0.670         0.09             1.0      0.020
# 3773            5.0             0.610         0.12             1.3      0.009
# 3904            5.0             0.455         0.18             1.9      0.036
# 3915            4.7             0.455         0.18             1.9      0.036
# 3918            6.4             0.350         0.28             1.6      0.037
# 4149            5.8             0.240         0.28             1.4      0.038
# 4645            5.0             0.240         0.34             1.1      0.034
# 4789            5.5             0.620         0.33             1.7      0.037
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 2945                 39.0                 150.0  0.98713  3.33       0.59
# 3367                 30.0                 114.0  0.98794  3.08       0.43
# 3370                 30.0                 114.0  0.98794  3.08       0.43
# 3673                 25.0                  93.0  0.98742  3.31       0.40
# 3676                 25.0                  93.0  0.98742  3.31       0.40
# 3710                  5.0                   9.0  0.98722  3.30       0.34
# 3773                 65.0                 100.0  0.98740  3.26       0.37
# 3904                 33.0                 106.0  0.98746  3.21       0.83
# 3915                 33.0                 106.0  0.98746  3.21       0.83
# 3918                 31.0                 113.0  0.98779  3.12       0.40
# 4149                 40.0                  76.0  0.98711  3.10       0.29
# 4645                 49.0                 158.0  0.98774  3.32       0.32
# 4789                 24.0                 118.0  0.98758  3.15       0.39
#
#       alcohol  quality
# 2945    14.00        8
# 3367    13.20        6
# 3370    13.20        6
# 3673    13.60        7
# 3676    13.60        7
# 3710    13.60        5
# 3773    13.50        5
# 3904    14.00        7
# 3915    14.00        7
# 3918    14.20        7
# 4149    13.90        7
# 4645    13.10        7
# 4789    13.55        6

# %%
print (len(test_frame))
print (test_frame.shape)
print (test_frame.columns)
# Out:
# 8
# (8, 13)
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality', 'dioxide sum'],
#       dtype='object')

# %%
plt.scatter(X['total sulfur dioxide'], X['volatile acidity'], c=y, alpha=0.4)
plt.colorbar()

# %% [markdown]
# ## Homework
#
# ### Problem 1
# plot histograms for couple of features from the dataframe

# %% [markdown]
# ### Problem 2
# Let's classify wines in:
#    * good means quality >= 7
#    * bad means quality <= 4
#    * mediocre means quality five or six
#
# Plot histograms of all features for good and bad wines. Which feature is the most discriminative?

# %% [markdown]
# ### Problem 3
# Plot some scatter plots:
#    - alcohol vs fixed acidity for good and bad wines, what can we say about good wines?
#    - alcohol vs fixed acidity for quality=5 and quality=6
#    - alcohol vs density for good and bad wines. What can we conclude?

# %% [markdown]
# # References
# 1. [matplotlib gallery](http://matplotlib.org/gallery.html)
# 2. [10 minutes to pandas](http://pandas.pydata.org/pandas-docs/stable/10min.html)
#     * almost any question about these tools is already answered on stackoverflow
